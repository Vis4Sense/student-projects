# %% [markdown]
# # Demo for Trading Backtesting

# %% [markdown]
# I have a previous project which is helpful to simply have something as a simple single stock backtester.
#
# It is important to note that this does not include a universe of tickers or have shorting mechanics (*just has long positions and take profit/stop loss logic*)

# %%
import pandas as pd 
from enum import Enum
from datetime import datetime
import uuid 


prices = pd.read_csv('Nvidia2024-2014.csv')
prices.rename(columns={'Close/Last': 'Close'}, inplace=True)

usd_to_gbp_rate = 0.76

price_columns = ['Close', 'Open', 'High', 'Low']

prices['Date'] = pd.to_datetime(prices['Date'], format='%m/%d/%Y').dt.strftime('%Y-%m-%d')


for col in price_columns:
    prices[col] = prices[col].astype(str).replace({'\\$': ''}, regex=True).astype(float)

for col in price_columns:
    prices[col] = prices[col] * usd_to_gbp_rate
prices.head()
# Out:
#          Date    Close     Volume     Open       High        Low
# 0  2024-10-07  97.0672  346250200  94.9924  99.286400  94.962000
# 1  2024-10-04  94.9392  244465600  94.9544  95.030400  92.590800
# 2  2024-10-03  93.3660  277118000  91.8992  94.513600  91.458476
# 3  2024-10-02  90.3260  221845900  88.4944  90.728800  87.506400
# 4  2024-10-01  88.9200  302094500  92.5414  93.050676  88.000400

# %% [markdown]
# ## Initial framework for dummy trades

# %%
INITIAL_WALLET_CASH = 5_000_000
STANDARD_LOT = 100000

class Side(Enum):
    BUY = 'BUY'
    SELL = 'SELL'
    
class Currency(Enum):
    GBP = 'GBP'
    USD = 'USD'
    
class Position:
    def __init__(self,
                 date:datetime,
                 size:int,
                 price,
                 currency:Currency,
                 side:Side):
        
        self._id = str(uuid.uuid4())
        self._date = date
        self._currency = currency
        self._price = price
        self._size = size
        self._side = side
        
class Order:
    def __init__(self,
                 position:Position):
        self._id = str(uuid.uuid4())
        self._position = position
    
    def describe(self):
        return f"<Order id: {self._id} position: {self._position}>"

class Portfolio:
    
    def __init__(self):
        self.cash_wallet = INITIAL_WALLET_CASH  # wallet is in GBP
        self.current_positions = {}
        self.closed_positions = {}
    
    def add_position(self,position):
        self.current_positions[position._id] = position
        self.deduct_from_wallet(self.calculate_deduction(position))
                
    def sell_position(self,position:Position):
        self.current_positions.pop(position._id)
        self.closed_positions[position._id] = position
    
    def get_wallet_value(self):
        return self.cash_wallet
    
    def deduct_from_wallet(self,amount):
        self.cash_wallet -= amount
        
    def add_to_wallet(self,amount):
        self.cash_wallet += amount
        
    def calculate_fees(self,position:Position):
        fee = position._size * 2 #broker fee is £2 per standard lot 
        print("FEE CHARGED: £",fee)
        return fee 
    
    def calculate_total_cost_in_gbp(self,position:Position):
        if(position._currency == Currency.GBP):
            return position._price * (position._size * STANDARD_LOT)
        # elif(position._currency == Currency.USD):
        #     return position._price * current_gbp_price  * (position._size * 100000) # x100000 for standard lot

    def calculate_deduction(self,position):
        return self.calculate_total_cost_in_gbp(position) + self.calculate_fees(position)

# %% [markdown]
# ## Take Profit and Stop Loss mechanics

# %%
def check_take_profit(FIXED_LOT_SIZE, A_REALLY_BIG_NUMBER, orders, tp_prices, row, currentP, date):
    if (tp_prices != []):
        cTP = min(tp_prices)
            
        while(currentP>=cTP):
            sell_position = Position(date,FIXED_LOT_SIZE,row.Open,Currency.GBP,Side.SELL)
            sell_order = Order(sell_position)
            orders[sell_order._id] = sell_order
                
            tp_prices.pop(tp_prices.index(cTP))
            try:
                cTP = min(tp_prices)
            except ValueError:
                cTP = A_REALLY_BIG_NUMBER

def check_stop_loss(FIXED_LOT_SIZE, A_REALLY_SMALL_NUMBER, orders, sl_prices, row, currentP, date):
    if (sl_prices != []):
        cSL = max(sl_prices)

        while(currentP<=cSL):
            sell_position = Position(date,FIXED_LOT_SIZE,row.Open,Currency.GBP,Side.SELL)
            sell_order = Order(sell_position)
            orders[sell_order._id] = sell_order

            sl_prices.pop(sl_prices.index(cSL))
            try:
                cSL = max(sl_prices)

            except ValueError:
                cSL = A_REALLY_SMALL_NUMBER

# %% [markdown]
# ## Setup indicators
#
# Can add more strategies or remove ones that might not be impactful

# %%
def setup_indicators(rsi_level, bb_mult, macd_period, data):
     # calculate Bollinger Bands
    data['MA20'] = data['Close'].rolling(window=20).mean()
    data['MA20_std'] = data['Close'].rolling(window=20).std()
    data['Upper_band'] = data['MA20'] + (data['MA20_std'] * bb_mult)
    data['Lower_band'] = data['MA20'] - (data['MA20_std'] * bb_mult)
    
    # calculate RSI
    period = 14
    delta = data['Open'].diff()
    delta = delta[1:]
    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0
    AVG_Gain = up.rolling(window=period).mean()
    AVG_Loss = abs(down.rolling(window=period).mean())
    RS = AVG_Gain / AVG_Loss
    RSI = 100.0 - (100.0 / (1.0 + RS))
    data['RSI'] = RSI

     # calculate Moving Average Convergence Divergence (MACD)
    period_short = macd_period[0]
    period_long = macd_period[1]
    data['EMA_short'] = sum(data['Close'][len(data)-period_short:])/period_short
    data['EMA_long'] = sum(data['Close'][len(data)-period_long:])/period_long
    data['MACD'] = data['EMA_short'] - data['EMA_long']
    data['Signal'] = sum(data['MACD'][len(data)-9:])/9

    # calculate Stochastic Oscillator
    period = 14
    data['L14'] = data['Low'].rolling(window=period).min()
    data['H14'] = data['High'].rolling(window=period).max()
    data['%K'] = (data['Close'] - data['L14']) / (data['H14'] - data['L14']) * 100
    data['%D'] = data['%K'].rolling(window=3).mean()
    return data

# %% [markdown]
# ## Strategy function
#
# edit the below cells to change the strategy, at the moment just use all the indicators to make a buy or sell order.
# can add more "*special cases*" for potential trading opportunities missed

# %%
FIXED_LOT_SIZE = 10
A_REALLY_BIG_NUMBER = 100000000
A_REALLY_SMALL_NUMBER = 0.0000000000001

def check_to_sell(orders, row, current_price, date, rsi_level):
    if(row["Close"] > row["Upper_band"] or row["RSI"] > rsi_level or row["MACD"] < row["Signal"] and (row["%K"] > 80 and row["%D"] > 80 and row["%K"]<row["%D"])):
        sell_position = Position(date,FIXED_LOT_SIZE,current_price,Currency.GBP,Side.SELL)
        sell_order = Order(sell_position)
        orders[sell_order._id] = sell_order

def check_to_buy(orders, tp_prices, sl_prices, row, current_price, date, rsi_level):
    if((row["Close"] < row["Lower_band"] and row["RSI"] < rsi_level) or row["MACD"] > row["Signal"] and (row["%K"] < 20 and row["%D"] < 20 and row["%K"]<row["%D"])):
        buy_position = Position(date,FIXED_LOT_SIZE,current_price,Currency.GBP,Side.BUY)
        buy_order = Order(buy_position)
        orders[buy_order._id] = buy_order
        tp_prices.append(row["Upper_band"])
        sl_prices.append(row["Lower_band"])

# %%
def strategy(rsi_level, bb_mult, macd_period, data):
    
    orders = {}
    tp_prices=[]
    sl_prices=[]
    
    data = setup_indicators(rsi_level, bb_mult, macd_period, data)
    
    for index,row in data.iterrows():
        current_price = row["Open"]+row["Close"]/2

        date = datetime.strptime(str(row["Date"]),'%Y-%m-%d').date()
        
        check_take_profit(FIXED_LOT_SIZE, A_REALLY_BIG_NUMBER, orders, tp_prices, row, current_price, date)
        check_stop_loss(FIXED_LOT_SIZE, A_REALLY_SMALL_NUMBER, orders, sl_prices, row, current_price, date)

        
        check_to_buy(orders, tp_prices, sl_prices, row, current_price, date, rsi_level[0])
            

        check_to_sell(orders, row, current_price, date, rsi_level[1])

    return orders

# %% [markdown]
# ## Backtest function
#
# At the moment this just goes through all the orders made from the strategy function and simulates how profitiable it would be if the orders were made.

# %%
def backtest_strategy(rsi_level, bb_mult, macd_period, data):
    
    portfolio = Portfolio()
    order_queue = strategy(rsi_level, bb_mult, macd_period, data)
    
    for index, order in order_queue.items():

        print(f"Side is {order._position._side}")
        print("Current P/L:", portfolio.cash_wallet - INITIAL_WALLET_CASH)

        # BUY orders
        if order._position._side == Side.BUY:
            if portfolio.calculate_total_cost_in_gbp(order._position) <= portfolio.cash_wallet:
                portfolio.add_position(order._position)  # Deduct cash
                print(f"BUY ORDER FILLED: (ID) {str(order._id).upper()}")
            else: 
                print("INSUFFICIENT CASH FOR BUY ORDER")
        
        # SELL orders
        elif order._position._side == Side.SELL:
            # Find the earliest matching BUY position (by size) to sell
            matching_position = next(
                (pos for pos in portfolio.current_positions.values()
                 if pos._side == Side.BUY and pos._size == order._position._size),
                None
            )
            
            if matching_position:
                sale_earning = order._position._price * (order._position._size * STANDARD_LOT)
                buy_cost = matching_position._price * (matching_position._size * STANDARD_LOT)
                portfolio.add_to_wallet(sale_earning)
                portfolio.sell_position(matching_position)  # Remove the matching BUY position                
                portfolio.add_to_wallet(buy_cost)
                fee = portfolio.calculate_fees(order._position)
                portfolio.deduct_from_wallet(fee)

                print(f"SELL ORDER FILLED: (ID) {str(order._id).upper()}")
            else:
                print("NO MATCHING BUY POSITION FOUND")
    
    # After all orders processed
    print("ALL ORDERS HAVE BEEN FILLED.")
    print("BOOK CASH LEVEL:", ("£{:,.2f}".format(portfolio.cash_wallet)))

    pnl = portfolio.cash_wallet - INITIAL_WALLET_CASH

    if pnl < 0:
        print("TOTAL LOSS:", ("£{:,.2f}".format(abs(pnl))))
    else:
        print("TOTAL PROFIT:", ("£{:,.2f}".format(pnl)))

    roi = (pnl / INITIAL_WALLET_CASH) * 100
    print("RATE ON INVESTMENT: {:.2f}%".format(roi))

    return pnl

# %% [markdown]
# ## Function to test best params for strategy

# %%
import itertools



def test_strategy(data):
    params_for_testing = define_params()
    rsi_levels,bollinger_mults,macd_periods = params_for_testing[0],params_for_testing[1],params_for_testing[2]

    # Run grid search for optimization
    best_pnl = float('-inf')
    best_params = None

    for rsi_level, bb_mult, macd_period in itertools.product(rsi_levels, bollinger_mults, macd_periods):
        pnl = backtest_strategy(rsi_level, bb_mult, macd_period, data)
        if pnl > best_pnl:
            best_pnl = pnl
            best_params = (rsi_level, bb_mult, macd_period)

    print("Best PnL:", best_pnl)
    roi = (best_pnl / INITIAL_WALLET_CASH) * 100
    print("RATE ON INVESTMENT: {:.2f}%".format(roi))
    print(f"Optimal Parameters:\nRSI: low - {best_params[0][0]} high - {best_params[0][1]}\nBollinger Bands STD: {best_params[1]}\nMACD Time Period: short - {best_params[2][0]} long - {best_params[2][1]}")
    print(f"rsi_levels {rsi_levels}, bol {bollinger_mults} and macd {macd_periods}")

def define_params():
    rsi_levels = [(low, high) for low in range(25, 40, 5) for high in range(65, 75, 5)]
    bollinger_mults = [x / 100 for x in range(150, 201, 25)]  # 1.50, 1.75, 2.00, 2.25, 2.50
    macd_periods = [(short, long) for short in range(10, 13) for long in range(24, 27)]  # Short: 10-11, Long: 12-14

    num_combinations = len(rsi_levels) * len(bollinger_mults) * len(macd_periods)

    print(f"Number of RSI: {len(rsi_levels)}\nNumber of bollinger mults: {len(bollinger_mults)}\nNumber of MACD periods: {len(macd_periods)}\nNumber of combinations: {num_combinations}")

    return (rsi_levels,bollinger_mults,macd_periods)

# %% [markdown]
# ## WARNING
#
# **THIS IS A BRUTEFORCE APPROACH AND SO RESULTS IN A LOT OF COMBINATIONS**
#
# You can refine the search space however, I saw this resulted in less trades being made netting 0% ROI. You can also change the ranges of the parameters being tested
#
# Run the function below to check the number of combinations and to find what can be reduced

# %%
define_params()
# Out:
# Number of RSI: 6
# Number of bollinger mults: 3
# Number of MACD periods: 9
# Number of combinations: 162
# ([(25, 65), (25, 70), (30, 65), (30, 70), (35, 65), (35, 70)],
#  [1.5, 1.75, 2.0],
#  [(10, 24),
#   (10, 25),
#   (10, 26),
#   (11, 24),
#   (11, 25),
#   (11, 26),
#   (12, 24),
#   (12, 25),
#   (12, 26)])

# %% [markdown]
# ## BEST STRATEGY?
#
# RSI: low - 35 high - 65 <br>
# Bollinger Bands STD: 1.5 <br>
# MACD Time Period: short - 10 long - 24

# %%
backtest_strategy((35,65),1.5,(10,24),prices)
# Out:
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# INSUFFICIENT CASH FOR BUY ORDER
# Side is Side.SELL
# Current P/L: 0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 9E8BB102-CD4A-4F67-8AAD-D942AD04110F
# Side is Side.SELL
# Current P/L: -4933180.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) CE463E75-1FF1-48EF-8820-A2E4F8AADF6F
# Side is Side.BUY
# Current P/L: 3324960.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 576B8FFF-ACB9-4DD8-9F7D-A7DCE21FB122
# Side is Side.SELL
# Current P/L: -1653060.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) AEABD30B-02DF-4B75-814E-3BBA460BF763
# Side is Side.BUY
# Current P/L: 6608120.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 90C163A5-B6C8-4340-B5EC-F99995570698
# Side is Side.SELL
# Current P/L: 1638840.000000001
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) B66EE1AB-86E4-4B2A-9C69-6816F8CA4914
# Side is Side.SELL
# Current P/L: 9987040.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 9987040.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 535467EE-706E-433A-B9CE-D03B8E358989
# Side is Side.SELL
# Current P/L: 5267420.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 3F894163-F594-40C0-8719-0311D98EB78B
# Side is Side.BUY
# Current P/L: 13038020.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 90AC3639-5398-4569-A5FB-40909E8BBA63
# Side is Side.SELL
# Current P/L: 8455390.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 63B4B338-D3B9-4C42-9E5C-24C0CC13E0D3
# Side is Side.SELL
# Current P/L: 16210828.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 16210828.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 16210828.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 16210828.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 16210828.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 07744F2F-A54A-4C16-89F3-57E29A643414
# Side is Side.SELL
# Current P/L: 11931666.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 84510057-0A93-408F-AC4E-34DED2F74C37
# Side is Side.BUY
# Current P/L: 19108364.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) B38C0614-0C81-4DB7-8502-42D0215A5F26
# Side is Side.SELL
# Current P/L: 14780068.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 3FB261DE-E57C-4A36-B1D2-4C9748A30558
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 22083952.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 22083952.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 11B7F630-287B-4E88-8982-27385FC099F9
# Side is Side.SELL
# Current P/L: 17634740.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 4AEDF3E0-6670-43BE-BA85-4AE704494963
# Side is Side.BUY
# Current P/L: 25082720.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 2F089D99-76F6-40D8-B716-0B44726A7F51
# Side is Side.SELL
# Current P/L: 20590378.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) CB476396-CC65-4844-9ADE-16E64C15995E
# Side is Side.BUY
# Current P/L: 28130280.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) F186578B-0C42-45EA-B548-3D97D00C5FC6
# Side is Side.SELL
# Current P/L: 23780210.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 813C1C01-719B-48D9-BAEB-FC22B5176D26
# Side is Side.SELL
# Current P/L: 31046740.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 31046740.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 31046740.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 31046740.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 31046740.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 31046740.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) E3A43E9F-8521-4BA8-A4B1-554B732B3E17
# Side is Side.SELL
# Current P/L: 26926912.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) CE8A3731-5A6A-4C7B-88ED-F76B3A5875C9
# Side is Side.SELL
# Current P/L: 33841448.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 33841448.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 33841448.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# ...
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 682AAD30-FDA2-4515-B13E-9A9A6014DE0D
# Side is Side.BUY
# Current P/L: 341371184.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 93F9965E-417C-4792-B053-2A3C3A6F0382
# Side is Side.SELL
# Current P/L: 340628872.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) FD34A9F0-F1FD-48F2-8ED6-C42519F9F05C
# Side is Side.BUY
# Current P/L: 341863472.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 75960062-0CE6-497D-9F62-AA5FAB1FA4DC
# Side is Side.SELL
# Current P/L: 341122490.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 6940DD84-3B17-4FC9-936D-08904E023387
# Side is Side.BUY
# Current P/L: 342353784.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) D1A6D99B-EC3B-487D-A6AF-30190D61250B
# Side is Side.SELL
# Current P/L: 341616222.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 0010DFBE-7B47-400A-8248-659A2E455733
# Side is Side.BUY
# Current P/L: 342831632.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) E1FAF385-211F-4172-93BD-F08016286EDE
# Side is Side.SELL
# Current P/L: 342109080.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 8B2382BB-841C-4D39-A57A-C92213E1220F
# Side is Side.BUY
# Current P/L: 343305832.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 0C8D08EC-9854-43F2-9F5F-AEF6BA2D9188
# Side is Side.SELL
# Current P/L: 342590082.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 58CE03CC-64DE-4EA1-91D3-C61D1A8E6471
# Side is Side.SELL
# Current P/L: 343762552.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 343762552.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) ADEC98F6-91C0-48AF-A370-C5860AD59230
# Side is Side.SELL
# Current P/L: 343070172.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) BA7547DE-ED92-4CD7-A381-673EF020D2B4
# Side is Side.BUY
# Current P/L: 344230824.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 186AD9A6-9C34-4E3A-ACD8-9AE38E4BB362
# Side is Side.SELL
# Current P/L: 343532858.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 476E72CD-1070-4AF0-A1E5-86F45C9445E2
# Side is Side.BUY
# Current P/L: 344685492.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 0D6460D4-5B77-4156-ADCF-1C3DF8EAF7C9
# Side is Side.SELL
# Current P/L: 343996608.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) E935992E-7E61-4F89-B1F3-426B31B51B1D
# Side is Side.SELL
# Current P/L: 345132940.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 345132940.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 8A4D0BC1-A0E9-4EAB-B4E5-10C06BC5D935
# Side is Side.SELL
# Current P/L: 344460168.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 486079F7-4539-4E39-A2E8-D91E38C4A69C
# Side is Side.BUY
# Current P/L: 345581528.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) D5D3891C-DECA-4252-AE35-0DE3CEF90ADD
# Side is Side.SELL
# Current P/L: 344911530.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) F26832DB-9926-4AAC-890C-164C422DCE54
# Side is Side.BUY
# Current P/L: 346032396.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 177B5CCA-A3DF-40D4-B4C5-E02D67673817
# Side is Side.SELL
# Current P/L: 345357154.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 365FB405-F3EC-4ADE-8F1E-F8AA176AE947
# Side is Side.SELL
# Current P/L: 346466696.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 346466696.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 346466696.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 346466696.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 346466696.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 346466696.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 190D9E40-0AEB-4057-BD3D-140E4939204E
# Side is Side.SELL
# Current P/L: 345812924.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) A1E1298E-1F76-441B-9EDB-2F7137616216
# Side is Side.SELL
# Current P/L: 346904036.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 346904036.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 346904036.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 346904036.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 346904036.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 346904036.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 93075388-0445-447D-BC83-28E36FB277D1
# Side is Side.SELL
# Current P/L: 346281424.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 4CB955D1-ECF8-415C-9B72-61D00FCE6497
# Side is Side.SELL
# Current P/L: 347332256.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 347332256.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 347332256.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 347332256.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 3BDF34A4-0932-468B-A736-561C3EEFE204
# Side is Side.SELL
# Current P/L: 346727162.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 75DA4634-1033-4CF7-BB02-BC4554782FEF
# Side is Side.SELL
# Current P/L: 347742996.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 347742996.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 347742996.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 347742996.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 347742996.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 8C82EAAA-7F07-4A08-982E-6FA41D168554
# Side is Side.SELL
# Current P/L: 347161044.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) DC925342-EC88-43D1-87D9-17ABB4BD2628
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 348160956.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 348160956.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 9128BD7E-3B99-4D97-9ADB-CFBB4EE69A68
# Side is Side.SELL
# Current P/L: 347556736.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 709C5A75-5964-4678-B394-2FABB92F9478
# Side is Side.BUY
# Current P/L: 348562424.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 05FB2244-867F-4E38-AAD2-17962A984D23
# Side is Side.SELL
# Current P/L: 347963562.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) CACED4A1-EDF1-4D65-8E9D-405F3B56B9E1
# Side is Side.BUY
# Current P/L: 348969212.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) D82D5293-DAF3-4E8F-9AE2-F2BF01BAA773
# Side is Side.SELL
# Current P/L: 348378482.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) EBD72F0C-E329-461B-A937-86DE815B0FDD
# Side is Side.SELL
# Current P/L: 349394620.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 349394620.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 349394620.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 349394620.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 4654364A-CFA9-434D-95FC-79C072337CA6
# Side is Side.SELL
# Current P/L: 348797924.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 869ABC3B-8D35-4AE8-9781-7D7CC56933EA
# Side is Side.BUY
# Current P/L: 349782180.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) E887D112-730C-4AC6-B255-19861E8E2393
# Side is Side.SELL
# Current P/L: 349195516.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) A01FE661-B323-49C5-951C-C558C2142C87
# Side is Side.BUY
# Current P/L: 350167460.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) D6459914-4540-4E30-B217-5545C3BC838C
# Side is Side.SELL
# Current P/L: 349588510.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 6D437602-FCF5-46B0-847B-F04F23E6BAB9
# Side is Side.BUY
# Current P/L: 350556388.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) C54E27E5-D804-473C-85F6-AA95FAD23C09
# Side is Side.SELL
# Current P/L: 349973600.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) CE612307-D048-4653-BB53-DDFA2CA5B6D8
# Side is Side.BUY
# Current P/L: 350939768.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) A72F1370-5BE0-4AEE-BF07-AACBA7B8A40A
# Side is Side.SELL
# Current P/L: 350361730.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) E88344F1-2A1B-48A6-8E1F-8244C5C48B18
# Side is Side.BUY
# Current P/L: 351320716.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 5AA113F4-F7EB-4644-83DA-9929ECDE10B6
# Side is Side.SELL
# Current P/L: 350748188.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) C2969DF5-D417-4D81-8D85-C13340C3D297
# Side is Side.BUY
# Current P/L: 351696116.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) E03985CF-4169-472E-A6B2-052F0CA787D4
# Side is Side.SELL
# Current P/L: 351129592.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 9CADE4EA-4BA2-4ECA-AAAC-696F6BFE4654
# Side is Side.BUY
# Current P/L: 352063156.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 04F71BA6-F52C-42FC-9877-2D601B7E4A4D
# Side is Side.SELL
# Current P/L: 351509666.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 4C135ACF-9AE6-4F32-ACD5-EC72851632D0
# Side is Side.BUY
# Current P/L: 352436276.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) D560E179-C2FC-48C5-88D7-C47B4BF5BF18
# Side is Side.SELL
# Current P/L: 351880658.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 83265655-FDED-4869-99DF-BA1602461A56
# Side is Side.BUY
# Current P/L: 352803316.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 0FC277FE-5CAD-4CE1-8936-EFDFD93F91CB
# Side is Side.SELL
# Current P/L: 352242264.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) F9910674-D945-44B6-BED4-E0131BAC717F
# Side is Side.SELL
# Current P/L: 353188976.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 353188976.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 353188976.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 353188976.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 353188976.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 353188976.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) D7192746-198E-45FB-9432-5457B75259A9
# Side is Side.SELL
# Current P/L: 352627544.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) CF68BF48-CE4A-4C5D-B181-66B007A49AB7
# Side is Side.BUY
# Current P/L: 353560804.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 2D3591CE-379B-415E-9079-4F47F640F4BA
# Side is Side.SELL
# Current P/L: 353000968.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) C2FEFEA1-2895-404C-9936-BAD84B19EF7E
# Side is Side.BUY
# Current P/L: 353935444.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 3BA652DE-97A9-419D-AAB4-E0A24A9B0A65
# Side is Side.SELL
# Current P/L: 353375000.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 3BD355E7-4AD4-4422-8317-2B153727B946
# Side is Side.BUY
# Current P/L: 354309932.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 37027F65-75DC-4291-AEAC-5EFB1A3DA00D
# Side is Side.SELL
# Current P/L: 353748766.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 3344A483-CE7B-49E3-AEF9-F089A1606B84
# Side is Side.SELL
# Current P/L: 354687992.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 354687992.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 656F4288-206F-4FD1-A6F4-6F55E9613513
# Side is Side.SELL
# Current P/L: 354153958.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) CA7AB547-61F1-4490-8030-18B8E6E90D8D
# Side is Side.SELL
# Current P/L: 355046140.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 355046140.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 355046140.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 858ED7BE-E87F-4DA3-82F0-74E9CAFC704B
# Side is Side.SELL
# Current P/L: 354515906.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 4089D75F-036D-4015-86B1-B339F3C259E2
# Side is Side.BUY
# Current P/L: 355396992.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) A194E1F6-E890-40B8-82DB-4F9A6F1658AE
# Side is Side.SELL
# Current P/L: 354870444.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 163D476B-31DF-4008-AD29-C164AC01C7AA
# Side is Side.BUY
# Current P/L: 355746552.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 2AACAC1C-0E02-4F1F-9B59-2D7D6F97F470
# Side is Side.SELL
# Current P/L: 355221372.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) F9F63347-0FB4-421F-A791-31E7F78EF48A
# Side is Side.BUY
# Current P/L: 356092312.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 566B8970-BBAA-4920-AA66-847A70A6A407
# Side is Side.SELL
# Current P/L: 355572794.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 9EE20B61-019C-48FD-938A-1A230A0021B6
# Side is Side.BUY
# Current P/L: 356439744.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 203D6EFD-6DD1-49B0-B6D0-D3600E72FEF5
# Side is Side.SELL
# Current P/L: 355922278.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 0FE01092-4FB1-4ACB-BA4D-2017FC4AF098
# Side is Side.SELL
# Current P/L: 356776004.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 356776004.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 356776004.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 356776004.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 356776004.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 356776004.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 356776004.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 356776004.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 8E87CE52-8024-44DA-8B3B-701C482151A7
# Side is Side.SELL
# Current P/L: 356278070.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) B64DB458-EF46-4A56-924F-020C54B3ECA6
# Side is Side.BUY
# Current P/L: 357111504.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) BF1B7CBC-B96D-4C96-AD84-9C9110144BD4
# Side is Side.SELL
# Current P/L: 356610454.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) F9B0526F-FA92-46A1-8138-A126C16A2D0A
# Side is Side.SELL
# Current P/L: 357436972.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 357436972.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 357436972.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 594DA23D-57E9-49D4-9E16-F69118D20445
# Side is Side.SELL
# Current P/L: 356945650.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) CA8D9B90-68E6-4A3E-A2BB-0460E7D58619
# Side is Side.SELL
# Current P/L: 357758640.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.SELL
# Current P/L: 357758640.0
# NO MATCHING BUY POSITION FOUND
# Side is Side.BUY
# Current P/L: 357758640.0
# FEE CHARGED: £ 20
# BUY ORDER FILLED: (ID) 93CE42FE-6E15-4765-A2CD-F41EA1678EC8
# Side is Side.SELL
# Current P/L: 357276932.0
# FEE CHARGED: £ 20
# SELL ORDER FILLED: (ID) 0A8D8833-DB2B-4C0A-A476-3B87FB7200D9
# ALL ORDERS HAVE BEEN FILLED.
# BOOK CASH LEVEL: £363,096,268.00
# TOTAL PROFIT: £358,096,268.00
# RATE ON INVESTMENT: 7161.93%
# 358096268.0

# %% [markdown]
# Something to note: at the moment the orders price is just the price the order was put in for so we are assuming each order is fulfilled. Obviously in a real market if we put in an order to sell something for 1,000,000 it wouldn't be fulfilled. The strategy just enters orders using the average of the opening and the close prices, (again not very realistic so requires improvement)
